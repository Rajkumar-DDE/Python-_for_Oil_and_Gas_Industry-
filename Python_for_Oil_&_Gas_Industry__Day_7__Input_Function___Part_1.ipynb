# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajkumar-DDE/Python-_for_Oil_and_Gas_Industry-/blob/main/Python_for_Oil_%26_Gas_Industry__Day_7__Input_Function___Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Input Function Part-1

# %%
# input function is we are given some input in computer then computer asking question for me.. see here

input('what do you do?')
# Out:
# what do you do?"working as Energy Professional"
# '"working as Energy Professional"'

# %%
#input function in a variable

name = input('what is your name?')
# Out:
# what is your name?Kumar

# %%
print(name)
# Out:
# Kumar

# %%
# Now i neeed output for 'Hi Kumar, Welcome back!'

print(f'Hi {name},Welcome back!')
# Out:
# Hi Kumar,Welcome back!

# %%
siblings = input('How many siblings do you have?')
# Out:
# How many siblings do you have?2

# %%
print(siblings)
# Out:
# 2

# %%
#I print statement  using concatenation, i have separate the statement # becaus 3 is a integer type convert to string
#input function always takes you answer is string  #whatever you give the data type like integer, complex input function convert to string
print('I have' + ' ' + siblings+ ' '+ 'siblings')
# Out:
# I have 2 siblings

# %%
#for example type of siblings
type(siblings)
# Out:
# str

# %%
age  = input('what is your age?')
dad_age = input('what is your dad age?')
# Out:
# what is your age?25
# what is your dad age?55

# %%
print(age)
# Out:
# 25

# %%
print(dad_age)
# Out:
# 55

# %%
#I creat variable for my age and my dad_age

age_sum = age+dad_age

# %%
print(age_sum)  #this is not i expected output #becaus this come to string added only not differecial
# Out:
# 2555

# %%
print('a' + 'b')
# Out:
# ab

# %% [markdown]
# **Use of int()**

# %%
#now i convert to integer value , they are two methods..see here
age_sum_2 = int(age) +int(dad_age)
print(age_sum_2)
# Out:
# 80

# %%
#pervious one is very long method,see here...

age_2  = int(input('what is your age?'))
dad_age_2 = int(input('what is your dad age?'))
# Out:
# what is your age?26
# what is your dad age?57

# %%
print(age_2+dad_age_2)
# Out:
# 83

# %% [markdown]
# # Today Python for oil and Gas industry Learning Completed
#
# **Thank you and Happy Learning**
